# %%
import pandas as pd

# %%
values = [['SA amplitude scaler',       r'$\alpha$',   '-',  'Gaussian',    r'$\mu_{\alpha}, \sigma_{\alpha}$',   1],
          ['Number of cells',           '$N_c$',       '-',  'Poisson',     r'$\lambda_c$',                      50],
          ['Spike train start',         'start',       'ms', 'Exponential', r'$\lambda_{start}$',                 1],
          ['Number of spikes per cell', '$N_s$',       '-',  'Poisson',     r'$\lambda_s$',                       3],
          ['AP amplitude scaler',       r'$\beta_a$',  '-',  'Gaussian',    r'$\mu_{\beta_a}, \sigma_{\beta_a}$', 1],
          ['AP duration scaler',        r'$\beta_d$',  '-',  'Gaussian',    r'$\mu_{\beta_d}, \sigma_{\beta_d}$', 2],
          ['Inter-spike interval',      '$t$',         'ms', 'Exponential', r'$\lambda_t$',                       1],
          ]
df = pd.DataFrame(columns=['Name', 'Symbol', 'Unit', 'Distribution', 'Parameters', 'Typical'], data=values)
df.to_csv("parameters.csv", index=False)
df
# Out:
#                         Name     Symbol Unit Distribution  \
# 0        SA amplitude scaler   $\alpha$    -     Gaussian
# 1            Number of cells      $N_c$    -      Poisson
# 2          Spike train start      start   ms  Exponential
# 3  Number of spikes per cell      $N_s$    -      Poisson
# 4        AP amplitude scaler  $\beta_a$    -     Gaussian
# 5         AP duration scaler  $\beta_d$    -     Gaussian
# 6       Inter-spike interval        $t$   ms  Exponential
#
#                           Parameters  Typical
# 0    $\mu_{\alpha}, \sigma_{\alpha}$        1
# 1                        $\lambda_c$       50
# 2                  $\lambda_{start}$        1
# 3                        $\lambda_s$        3
# 4  $\mu_{\beta_a}, \sigma_{\beta_a}$        1
# 5  $\mu_{\beta_d}, \sigma_{\beta_d}$        2
# 6                        $\lambda_t$        1
